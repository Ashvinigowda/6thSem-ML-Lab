# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from google.colab import files
import io

# Prompt user to upload the file
print('Dataset of Diabetes.csv')
uploaded = files.upload()

# Get the filename from the uploaded files
# Assuming only one file is uploaded or the first one is the correct one
filename = list(uploaded.keys())[0]

# Read the uploaded CSV file from memory
diabetes_df = pd.read_csv(io.BytesIO(uploaded[filename]))

# Display basic info
print("Dataset Info:")
diabetes_df.info()
# Out:
# Dataset of Diabetes.csv
#      <input type="file" id="files-735445d2-45db-42b9-850f-bc630771fdf5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-735445d2-45db-42b9-850f-bc630771fdf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
numeric_cols = diabetes_df.select_dtypes(include=np.number)
numeric_cols.fillna(numeric_cols.mean(), inplace=True)
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

numeric_cols = numeric_cols[
    ~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)
]

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()
diabetes_minmax = minmax_scaler.fit_transform(numeric_cols)

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()
diabetes_standardized = standard_scaler.fit_transform(numeric_cols)

# %%
print(diabetes_df)
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
# ADULT INCOME DATASET PREPROCESSING

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from google.colab import files
import io

# Prompt user to upload the file
print("Please upload the 'adult.csv' file.")
uploaded = files.upload()

# Get the filename from the uploaded files
# Assuming only one file is uploaded or the first one is the correct one
filename = list(uploaded.keys())[0]

# Read the uploaded CSV file from memory
adult_df = pd.read_csv(io.BytesIO(uploaded[filename]))

print("Dataset Info:")
adult_df.info()

print("\nFirst 5 rows:")
print(adult_df.head())
# Out:
# Please upload the 'adult.csv' file.
#      <input type="file" id="files-50babc31-24cc-41ab-91ef-ada573955c45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50babc31-24cc-41ab-91ef-ada573955c45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Replace '?' with NaN
adult_df.replace('?', np.nan, inplace=True)

# Fill missing categorical values with mode
for col in adult_df.select_dtypes(include='object').columns:
    adult_df[col].fillna(adult_df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-611161388.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adult_df[col].fillna(adult_df[col].mode()[0], inplace=True)

# %%
le = LabelEncoder()

for col in adult_df.select_dtypes(include='object').columns:
    adult_df[col] = le.fit_transform(adult_df[col])

# %%
# Select only numerical columns
numeric_cols = adult_df.select_dtypes(include=np.number)

Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

numeric_cols = numeric_cols[
    ~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)
]

# %%
minmax_scaler = MinMaxScaler()
adult_minmax = minmax_scaler.fit_transform(numeric_cols)

# %%
standard_scaler = StandardScaler()
adult_standardized = standard_scaler.fit_transform(numeric_cols)

# %%
print("Dataset Info:")
adult_df.info()

print("\nFirst 5 rows:")
print(adult_df.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  int64
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  int64
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  int64
#  6   occupation       48842 non-null  int64
#  7   relationship     48842 non-null  int64
#  8   race             48842 non-null  int64
#  9   gender           48842 non-null  int64
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  int64
#  14  income           48842 non-null  int64
# dtypes: int64(15)
# memory usage: 5.6 MB
#
# First 5 rows:
# ...
